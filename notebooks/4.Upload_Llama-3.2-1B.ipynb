# %% [markdown]
# # Upload Fine-Tuned Model to Hugging Face

# %%
from huggingface_hub import HfApi

api = HfApi()
api.create_repo("BMW-Llama-3.2-1B", exist_ok=True)
api.upload_folder(
    folder_path="../checkpoints/unsloth/Llama-3.2-1B-Instruct/merged_model",
    repo_id="Alwin-Yang/BMW-Llama-3.2-1B",
)
